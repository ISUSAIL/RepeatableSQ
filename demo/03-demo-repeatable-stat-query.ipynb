# %% [markdown]
# # Repeatable Statistical Inference Demo - Repeatable Statistical Query

# %%
# Add parent directory to path for imports
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List, Dict, Tuple
import warnings
warnings.filterwarnings('ignore')

# Import our implementations
from distributions import (
    Distribution01, BernoulliRare, BetaSkewed, 
    BimodalMixture, UniformSpike, TruncatedNormal
)

from stat_query import (
    RepeatableStatQuery, RepeatableTestConfig
)

# Set up plotting style with larger fonts
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14          # Increased from 12
plt.rcParams['axes.labelsize'] = 16     # Axis labels
plt.rcParams['axes.titlesize'] = 18     # Title size
plt.rcParams['xtick.labelsize'] = 14    # X-axis tick labels
plt.rcParams['ytick.labelsize'] = 14    # Y-axis tick labels
plt.rcParams['legend.fontsize'] = 14    # Legend font size
plt.rcParams['figure.titlesize'] = 20   # Figure title size

# %%
def demo_non_repeatable_basic_sq():
    """
    Demonstrate the non-repeatability of Algorithm 1 (Basic Statistical Query).
    
    Tests all distributions with both Monte Carlo and Importance Sampling.
    """
    print("="*80)
    print("NON-REPEATABLE BASIC STATISTICAL QUERY DEMONSTRATION")
    print("="*80)
    
    # Initialize testing framework
    test_engine = RepeatableStatQuery()
    
    # Test all distributions
    test_distributions = [
        BernoulliRare(p=0.05),                     # 1. Rare events
        BetaSkewed(alpha=0.5, beta=2.0),           # 2. Right-skewed
        TruncatedNormal(mu=0.3, sigma=0.15),       # 3. Truncated normal
        BimodalMixture(weight=0.3),                # 4. Bimodal mixture
        UniformSpike(spike_location=0.9, spike_prob=0.1)  # 5. Uniform with spike
    ]
    
    # Different configurations to show variability across parameter settings
    configs = [
        RepeatableTestConfig(gamma=0.02, c=0.05, beta=0.1, max_samples=3000, random_seed=None),
        RepeatableTestConfig(gamma=0.01, c=0.02, beta=0.05, max_samples=5000, random_seed=None),
    ]
    
    all_results = []
    
    for dist_idx, dist in enumerate(test_distributions):
        print(f"\n{'='*60}")
        print(f"DISTRIBUTION {dist_idx+1}: {dist.name}")
        print(f"True Mean: {dist.true_mean():.4f}")
        print('='*60)
        
        for config_idx, config in enumerate(configs):
            print(f"\nConfiguration {config_idx+1}: γ={config.gamma}, c={config.c}")
            print(f"Target Accuracy: {config.gamma}")
            print(f"Confidence Level: {1-config.c:.2%}")
            
            # Test Monte Carlo (MC)
            print(f"\n--- Monte Carlo Sampling ---")
            print("Trial | Estimate | Samples | Emp. Variance | Diff from True")
            print("-" * 65)
            
            mc_results = []
            for trial in range(8):  # More trials to show variability
                estimate, n_samples, emp_var = test_engine._algorithm1_basic_sq(
                    dist, None, config  # None = Monte Carlo
                )
                
                difference = abs(estimate - dist.true_mean())
                mc_results.append({
                    'trial': trial + 1,
                    'estimate': estimate,
                    'n_samples': n_samples,
                    'emp_variance': emp_var,
                    'difference': difference,
                    'method': 'MC'
                })
                
                print(f"{trial+1:5d} | {estimate:8.4f} | {n_samples:7d} | {emp_var:12.6f} | {difference:8.4f}")
            
            # Test Importance Sampling (IS) if available
            importance_dist = dist.suggest_importance_distribution()
            
            if importance_dist.name != dist.name:
                print(f"\n--- Importance Sampling with {importance_dist.name} ---")
                print("Trial | Estimate | Samples | Emp. Variance | Diff from True")
                print("-" * 65)
                
                is_results = []
                for trial in range(8):
                    estimate, n_samples, emp_var = test_engine._algorithm1_basic_sq(
                        dist, importance_dist, config  # Use importance distribution
                    )
                    
                    difference = abs(estimate - dist.true_mean())
                    is_results.append({
                        'trial': trial + 1,
                        'estimate': estimate,
                        'n_samples': n_samples,
                        'emp_variance': emp_var,
                        'difference': difference,
                        'method': 'IS'
                    })
                    
                    print(f"{trial+1:5d} | {estimate:8.4f} | {n_samples:7d} | {emp_var:12.6f} | {difference:8.4f}")
            else:
                is_results = []
                print(f"\n--- No Importance Sampling Available ---")
                print(f"(Same distribution suggested: {importance_dist.name})")
            
            # Analysis of variability for this distribution and config
            all_results_for_analysis = mc_results + is_results
            
            if len(all_results_for_analysis) > 0:
                estimates = [r['estimate'] for r in all_results_for_analysis]
                sample_counts = [r['n_samples'] for r in all_results_for_analysis]
                
                print(f"\n📊 VARIABILITY ANALYSIS:")
                print(f"   Estimate Range: [{min(estimates):.4f}, {max(estimates):.4f}]")
                print(f"   Estimate Std Dev: {np.std(estimates):.4f}")
                print(f"   Sample Count Range: [{min(sample_counts)}, {max(sample_counts)}]")
                print(f"   Avg Sample Count: {np.mean(sample_counts):.1f}")
                
                # Compare MC vs IS if both available
                if is_results:
                    mc_estimates = [r['estimate'] for r in mc_results]
                    is_estimates = [r['estimate'] for r in is_results]
                    print(f"   MC Estimate Std: {np.std(mc_estimates):.4f}")
                    print(f"   IS Estimate Std: {np.std(is_estimates):.4f}")
            
            all_results.extend(all_results_for_analysis)
    
    return all_results

# %%
# Demonstrate the non-repeatability problem first
basic_sq_results = demo_non_repeatable_basic_sq()
# Out:
# ================================================================================
# NON-REPEATABLE BASIC STATISTICAL QUERY DEMONSTRATION
# ================================================================================
#
# ============================================================
# DISTRIBUTION 1: Bernoulli(0.050)
# True Mean: 0.0500
# ============================================================
#
# Configuration 1: γ=0.02, c=0.05
# Target Accuracy: 0.02
# Confidence Level: 95.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.0437 |    1510 |     0.041798 |   0.0063
#     2 |   0.0483 |    1594 |     0.045973 |   0.0017
#     3 |   0.0495 |    1615 |     0.047082 |   0.0005
#     4 |   0.0462 |    1557 |     0.044104 |   0.0038
#     5 |   0.0479 |    1586 |     0.045623 |   0.0021
#     6 |   0.0419 |    1478 |     0.040189 |   0.0081
#     7 |   0.0458 |    1549 |     0.043735 |   0.0042
#     8 |   0.0530 |    1678 |     0.050226 |   0.0030
#
# --- Importance Sampling with Bernoulli(0.150) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.0517 |    1075 |     0.014508 |   0.0017
#     2 |   0.0459 |    1044 |     0.013289 |   0.0041
#     3 |   0.0503 |    1068 |     0.014225 |   0.0003
#     4 |   0.0506 |    1069 |     0.014286 |   0.0006
#     5 |   0.0486 |    1059 |     0.013882 |   0.0014
#     6 |   0.0558 |    1095 |     0.015331 |   0.0058
#     7 |   0.0459 |    1044 |     0.013289 |   0.0041
#     8 |   0.0456 |    1043 |     0.013223 |   0.0044
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.0419, 0.0558]
#    Estimate Std Dev: 0.0035
#    Sample Count Range: [1043, 1678]
#    Avg Sample Count: 1316.5
#    MC Estimate Std: 0.0032
#    IS Estimate Std: 0.0033
#
# Configuration 2: γ=0.01, c=0.02
# Target Accuracy: 0.01
# Confidence Level: 98.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.0522 |    5000 |     0.049475 |   0.0022
#     2 |   0.0508 |    5000 |     0.048219 |   0.0008
#     3 |   0.0462 |    5000 |     0.044066 |   0.0038
#     4 |   0.0496 |    5000 |     0.047140 |   0.0004
#     5 |   0.0452 |    5000 |     0.043157 |   0.0048
#     6 |   0.0448 |    5000 |     0.042793 |   0.0052
#     7 |   0.0524 |    5000 |     0.049654 |   0.0024
#     8 |   0.0516 |    5000 |     0.048937 |   0.0016
#
# --- Importance Sampling with Bernoulli(0.150) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.0476 |    3416 |     0.013652 |   0.0024
#     2 |   0.0490 |    3449 |     0.013955 |   0.0010
#     3 |   0.0524 |    3524 |     0.014657 |   0.0024
#     4 |   0.0504 |    3481 |     0.014253 |   0.0004
#     5 |   0.0518 |    3510 |     0.014530 |   0.0018
#     6 |   0.0531 |    3540 |     0.014796 |   0.0031
#     7 |   0.0510 |    3495 |     0.014383 |   0.0010
#     8 |   0.0503 |    3479 |     0.014237 |   0.0003
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.0448, 0.0531]
#    Estimate Std Dev: 0.0026
#    Sample Count Range: [3416, 5000]
#    Avg Sample Count: 4243.4
#    MC Estimate Std: 0.0030
#    IS Estimate Std: 0.0017
#
# ============================================================
# DISTRIBUTION 2: Beta(0.5, 2.0)
# True Mean: 0.2000
# ============================================================
#
# Configuration 1: γ=0.02, c=0.05
# Target Accuracy: 0.02
# Confidence Level: 95.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.2002 |    1544 |     0.043459 |   0.0002
#     2 |   0.1966 |    1561 |     0.044346 |   0.0034
#     3 |   0.2105 |    1665 |     0.049557 |   0.0105
#     4 |   0.2098 |    1634 |     0.047993 |   0.0098
#     5 |   0.2053 |    1649 |     0.048762 |   0.0053
#     6 |   0.1982 |    1573 |     0.044927 |   0.0018
#     7 |   0.2007 |    1595 |     0.046044 |   0.0007
#     8 |   0.1997 |    1579 |     0.045229 |   0.0003
#
# --- No Importance Sampling Available ---
# (Same distribution suggested: Beta(0.5, 2.0))
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.1966, 0.2105]
#    Estimate Std Dev: 0.0049
#    Sample Count Range: [1544, 1665]
#    Avg Sample Count: 1600.0
#
# Configuration 2: γ=0.01, c=0.02
# Target Accuracy: 0.01
# Confidence Level: 98.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.1970 |    5000 |     0.044830 |   0.0030
#     2 |   0.2042 |    5000 |     0.047530 |   0.0042
#     3 |   0.1975 |    5000 |     0.044552 |   0.0025
#     4 |   0.2020 |    5000 |     0.045268 |   0.0020
#     5 |   0.2033 |    5000 |     0.045867 |   0.0033
#     6 |   0.1966 |    5000 |     0.044713 |   0.0034
#     7 |   0.2017 |    5000 |     0.045185 |   0.0017
#     8 |   0.1979 |    5000 |     0.045629 |   0.0021
#
# --- No Importance Sampling Available ---
# (Same distribution suggested: Beta(0.5, 2.0))
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.1966, 0.2042]
#    Estimate Std Dev: 0.0029
#    Sample Count Range: [5000, 5000]
#    Avg Sample Count: 5000.0
#
# ============================================================
# DISTRIBUTION 3: TruncNorm(μ=0.30, σ=0.15)
# True Mean: 0.3083
# ============================================================
#
# Configuration 1: γ=0.02, c=0.05
# Target Accuracy: 0.02
# Confidence Level: 95.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.3098 |    1077 |     0.020989 |   0.0016
#     2 |   0.3079 |    1047 |     0.019649 |   0.0004
#     3 |   0.3118 |    1048 |     0.019700 |   0.0035
#     4 |   0.3160 |    1097 |     0.021893 |   0.0077
#     5 |   0.3063 |    1030 |     0.018879 |   0.0020
#     6 |   0.3042 |    1032 |     0.018965 |   0.0041
#     7 |   0.3056 |    1065 |     0.020464 |   0.0027
#     8 |   0.3069 |    1049 |     0.019714 |   0.0014
#
# --- Importance Sampling with Beta(1.0, 1.0) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.3101 |    3000 |     0.107585 |   0.0018
#     2 |   0.3067 |    3000 |     0.107474 |   0.0016
#     3 |   0.3091 |    3000 |     0.106881 |   0.0008
#     4 |   0.3066 |    3000 |     0.102407 |   0.0017
#     5 |   0.3101 |    3000 |     0.106070 |   0.0018
#     6 |   0.3050 |    3000 |     0.101578 |   0.0033
#     7 |   0.3104 |    3000 |     0.104342 |   0.0021
#     8 |   0.3067 |    3000 |     0.102929 |   0.0016
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.3042, 0.3160]
#    Estimate Std Dev: 0.0029
#    Sample Count Range: [1030, 3000]
#    Avg Sample Count: 2027.8
#    MC Estimate Std: 0.0036
#    IS Estimate Std: 0.0019
#
# Configuration 2: γ=0.01, c=0.02
# Target Accuracy: 0.01
# Confidence Level: 98.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.3073 |    3567 |     0.018905 |   0.0010
#     2 |   0.2997 |    3643 |     0.019651 |   0.0086
#     3 |   0.3071 |    3701 |     0.020231 |   0.0012
#     4 |   0.3070 |    3637 |     0.019595 |   0.0013
#     5 |   0.3111 |    3689 |     0.020106 |   0.0028
#     6 |   0.3093 |    3711 |     0.020332 |   0.0010
#     7 |   0.3092 |    3655 |     0.019771 |   0.0009
#     8 |   0.3118 |    3728 |     0.020501 |   0.0035
#
# --- Importance Sampling with Beta(1.0, 1.0) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.3087 |    5000 |     0.102791 |   0.0005
#     2 |   0.3069 |    5000 |     0.103163 |   0.0014
#     3 |   0.3062 |    5000 |     0.102456 |   0.0020
#     4 |   0.3079 |    5000 |     0.106117 |   0.0004
#     5 |   0.3074 |    5000 |     0.105090 |   0.0009
#     6 |   0.3077 |    5000 |     0.104302 |   0.0006
#     7 |   0.3073 |    5000 |     0.103590 |   0.0010
#     8 |   0.3103 |    5000 |     0.103222 |   0.0020
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.2997, 0.3118]
#    Estimate Std Dev: 0.0026
#    Sample Count Range: [3567, 5000]
#    Avg Sample Count: 4333.2
#    MC Estimate Std: 0.0035
#    IS Estimate Std: 0.0012
#
# ============================================================
# DISTRIBUTION 4: BiModal(w=0.30)
# True Mean: 0.6200
# ============================================================
#
# Configuration 1: γ=0.02, c=0.05
# Target Accuracy: 0.02
# Confidence Level: 95.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.6127 |    3000 |     0.119989 |   0.0073
#     2 |   0.6228 |    2990 |     0.118714 |   0.0028
#     3 |   0.6191 |    3000 |     0.122274 |   0.0009
#     4 |   0.6113 |    3000 |     0.123420 |   0.0087
#     5 |   0.6235 |    3000 |     0.122812 |   0.0035
#     6 |   0.6299 |    2981 |     0.118275 |   0.0099
#     7 |   0.6276 |    3000 |     0.120605 |   0.0076
#     8 |   0.6193 |    3000 |     0.121707 |   0.0007
#
# --- Importance Sampling with Beta(1.0, 1.0) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.6159 |    3000 |     1.225826 |   0.0041
#     2 |   0.6187 |    3000 |     1.298920 |   0.0013
#     3 |   0.6286 |    3000 |     1.440009 |   0.0086
#     4 |   0.6395 |    3000 |     2.061556 |   0.0195
#     5 |   0.6291 |    3000 |     2.745285 |   0.0091
#     6 |   0.5973 |    3000 |     1.374094 |   0.0227
#     7 |   0.6007 |    3000 |     0.958532 |   0.0193
#     8 |   0.6321 |    3000 |     1.265102 |   0.0121
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.5973, 0.6395]
#    Estimate Std Dev: 0.0109
#    Sample Count Range: [2981, 3000]
#    Avg Sample Count: 2998.2
#    MC Estimate Std: 0.0061
#    IS Estimate Std: 0.0141
#
# Configuration 2: γ=0.01, c=0.02
# Target Accuracy: 0.01
# Confidence Level: 98.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.6222 |    5000 |     0.119220 |   0.0022
#     2 |   0.6208 |    5000 |     0.121567 |   0.0008
#     3 |   0.6218 |    5000 |     0.121179 |   0.0018
#     4 |   0.6107 |    5000 |     0.124756 |   0.0093
#     5 |   0.6152 |    5000 |     0.121971 |   0.0048
#     6 |   0.6121 |    5000 |     0.120202 |   0.0079
#     7 |   0.6211 |    5000 |     0.118901 |   0.0011
#     8 |   0.6151 |    5000 |     0.119881 |   0.0049
#
# --- Importance Sampling with Beta(1.0, 1.0) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.6197 |    5000 |     1.677254 |   0.0003
#     2 |   0.6206 |    5000 |     2.251745 |   0.0006
#     3 |   0.6218 |    5000 |     2.332088 |   0.0018
#     4 |   0.6135 |    5000 |     2.888466 |   0.0065
#     5 |   0.6192 |    5000 |     3.256190 |   0.0008
#     6 |   0.6397 |    5000 |     1.996129 |   0.0197
#     7 |   0.6234 |    5000 |     1.818949 |   0.0034
#     8 |   0.6312 |    5000 |     3.823150 |   0.0112
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.6107, 0.6397]
#    Estimate Std Dev: 0.0069
#    Sample Count Range: [5000, 5000]
#    Avg Sample Count: 5000.0
#    MC Estimate Std: 0.0043
#    IS Estimate Std: 0.0076
#
# ============================================================
# DISTRIBUTION 5: UniformSpike(0.90, 0.10)
# True Mean: 0.5400
# ============================================================
#
# Configuration 1: γ=0.02, c=0.05
# Target Accuracy: 0.02
# Confidence Level: 95.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.5423 |    2419 |     0.088588 |   0.0023
#     2 |   0.5471 |    2453 |     0.090370 |   0.0071
#     3 |   0.5394 |    2432 |     0.089280 |   0.0006
#     4 |   0.5374 |    2382 |     0.086618 |   0.0026
#     5 |   0.5436 |    2397 |     0.087425 |   0.0036
#     6 |   0.5509 |    2359 |     0.085455 |   0.0109
#     7 |   0.5341 |    2436 |     0.089479 |   0.0059
#     8 |   0.5466 |    2458 |     0.090656 |   0.0066
#
# --- Importance Sampling with Beta(2.0, 1.5) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.5407 |    3000 |     0.479833 |   0.0007
#     2 |   0.5485 |    3000 |     0.470238 |   0.0085
#     3 |   0.5468 |    3000 |     0.514656 |   0.0068
#     4 |   0.5332 |    3000 |     0.466826 |   0.0068
#     5 |   0.5340 |    3000 |     0.446043 |   0.0060
#     6 |   0.4701 |    3000 |     0.450305 |   0.0699
#     7 |   0.5383 |    3000 |     0.468292 |   0.0017
#     8 |   0.5345 |    3000 |     0.393134 |   0.0055
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.4701, 0.5509]
#    Estimate Std Dev: 0.0181
#    Sample Count Range: [2359, 3000]
#    Avg Sample Count: 2708.5
#    MC Estimate Std: 0.0052
#    IS Estimate Std: 0.0236
#
# Configuration 2: γ=0.01, c=0.02
# Target Accuracy: 0.01
# Confidence Level: 98.00%
#
# --- Monte Carlo Sampling ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.5444 |    5000 |     0.087039 |   0.0044
#     2 |   0.5563 |    5000 |     0.088626 |   0.0163
#     3 |   0.5409 |    5000 |     0.088009 |   0.0009
#     4 |   0.5461 |    5000 |     0.089973 |   0.0061
#     5 |   0.5390 |    5000 |     0.088432 |   0.0010
#     6 |   0.5383 |    5000 |     0.090481 |   0.0017
#     7 |   0.5464 |    5000 |     0.088771 |   0.0064
#     8 |   0.5390 |    5000 |     0.088215 |   0.0010
#
# --- Importance Sampling with Beta(2.0, 1.5) ---
# Trial | Estimate | Samples | Emp. Variance | Diff from True
# -----------------------------------------------------------------
#     1 |   0.5385 |    5000 |     0.445784 |   0.0015
#     2 |   0.5360 |    5000 |     0.488727 |   0.0040
#     3 |   0.5534 |    5000 |     0.563268 |   0.0134
#     4 |   0.5368 |    5000 |     0.534491 |   0.0032
#     5 |   0.5320 |    5000 |     0.525079 |   0.0080
#     6 |   0.5327 |    5000 |     0.480468 |   0.0073
#     7 |   0.5370 |    5000 |     0.495211 |   0.0030
#     8 |   0.5336 |    5000 |     0.487262 |   0.0064
#
# 📊 VARIABILITY ANALYSIS:
#    Estimate Range: [0.5320, 0.5563]
#    Estimate Std Dev: 0.0068
#    Sample Count Range: [5000, 5000]
#    Avg Sample Count: 5000.0
#    MC Estimate Std: 0.0056
#    IS Estimate Std: 0.0064

# %%
def demo_repeatable_testing():
    """
    Demonstrate the repeatable testing framework from the paper.
    
    Shows:
    1. Exact repeatability with α-quantization
    2. Empirical Bernstein stopping criterion
    3. Monte Carlo vs Importance Sampling comparison
    4. Accuracy and efficiency guarantees
    """
    print("="*80)
    print("REPEATABLE STATISTICAL TESTING DEMONSTRATION")
    print("="*80)
    
    # Demonstrate parameter validation
    print("\n0. PARAMETER VALIDATION AND SUGGESTIONS")
    print("-" * 50)
    
    # Initialize testing framework
    test_engine = RepeatableStatQuery()
    
    # Test distributions (reduced for faster demo)
    test_distributions = [
        BernoulliRare(p=0.05),                     # 1. Rare events
        BetaSkewed(alpha=0.5, beta=2.0),           # 2. Right-skewed
        TruncatedNormal(mu=0.3, sigma=0.15),       # 3. Truncated normal
        BimodalMixture(weight=0.3)                 # 4. Bimodal mixture
    ]
    
    # Test configurations (ensure (1-c)² - (1-β) ≥ 0)
    configs = [
        RepeatableTestConfig(gamma=0.05, c=0.05, beta=0.1, max_samples=5000, random_seed=None),
        RepeatableTestConfig(gamma=0.05, c=0.02, beta=0.05, max_samples=10000, random_seed=None),
    ]
    
    print("\n1. REPEATABILITY DEMONSTRATION")
    print("-" * 50)
    print("Note: Repeatability is guaranteed with probability 1-β.")
    
    repeatability_results = []
    
    for dist in test_distributions:
        for config in configs:
            print(f"\n--- {dist.name} with γ={config.gamma} ---")
            
            # Monte Carlo repeatability (more trials to observe probabilistic failures)
            mc_result = test_engine.demonstrate_exact_repeatability(
                dist, None, config, n_trials=10
            )
            
            # Importance Sampling repeatability
            importance_dist = dist.suggest_importance_distribution()
            if importance_dist.name != dist.name:
                print(f"\nImportance Sampling with {importance_dist.name}:")
                is_result = test_engine.demonstrate_exact_repeatability(
                    dist, importance_dist, config, n_trials=10
                )
            else:
                is_result = None
            
            repeatability_results.append({
                'distribution': dist.name,
                'monte_carlo': mc_result,
                'importance_sampling': is_result
            })
    
    print("\n2. EMPIRICAL BERNSTEIN STOPPING CRITERION")
    print("-" * 50)
    
    # Compare with different accuracy parameters
    bernstein_results = []
    test_dist = BernoulliRare(p=0.05)
    
    for gamma in [0.05, 0.02]:
        config = RepeatableTestConfig(gamma=gamma, c=0.05, beta=0.1, max_samples=3000, random_seed=None)
        result = test_engine.algorithm2_repeatable_test(test_dist, None, config)
        
        print(f"γ={gamma:.3f}: n={result.n_samples}, "
              f"empirical_var={result.empirical_variance:.6f}, "
              f"converged={result.is_converged}")
        
        bernstein_results.append(result)

# %%
demo_repeatable_testing()
# Out:
# ================================================================================
# REPEATABLE STATISTICAL TESTING DEMONSTRATION
# ================================================================================
#
# 0. PARAMETER VALIDATION AND SUGGESTIONS
# --------------------------------------------------
#
# 1. REPEATABILITY DEMONSTRATION
# --------------------------------------------------
# Note: Repeatability is guaranteed with probability 1-β.
#
# --- Bernoulli(0.050) with γ=0.05 ---
# Demonstrating exact repeatability for Bernoulli(0.050)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.045226, quantized=0.045455, n=398
#   Trial 2: original=0.058824, quantized=0.045455, n=442
#   Trial 3: original=0.045226, quantized=0.045455, n=398
#   Trial 4: original=0.039578, quantized=0.045455, n=379
#   Trial 5: original=0.043367, quantized=0.045455, n=392
#   Trial 6: original=0.052257, quantized=0.045455, n=421
#   Trial 7: original=0.055556, quantized=0.045455, n=432
#   Trial 8: original=0.055556, quantized=0.045455, n=432
#   Trial 9: original=0.050481, quantized=0.045455, n=416
#   Trial 10: original=0.045226, quantized=0.045455, n=398
#   ✓ All 10 trials exactly repeatable!
#
# Importance Sampling with Bernoulli(0.150):
# Demonstrating exact repeatability for Bernoulli(0.050)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.048940, quantized=0.045455, n=333
#   Trial 2: original=0.053665, quantized=0.045455, n=338
#   Trial 3: original=0.054605, quantized=0.045455, n=339
#   Trial 4: original=0.040450, quantized=0.045455, n=323
#   Trial 5: original=0.064110, quantized=0.045455, n=348
#   Trial 6: original=0.047989, quantized=0.045455, n=332
#   Trial 7: original=0.048940, quantized=0.045455, n=333
#   Trial 8: original=0.059275, quantized=0.045455, n=344
#   Trial 9: original=0.058344, quantized=0.045455, n=343
#   Trial 10: original=0.060403, quantized=0.045455, n=344
#   ✓ All 10 trials exactly repeatable!
#
# --- Bernoulli(0.050) with γ=0.05 ---
# Demonstrating exact repeatability for Bernoulli(0.050)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.054307, quantized=0.041667, n=534
#   Trial 2: original=0.058288, quantized=0.041667, n=549
#   Trial 3: original=0.043033, quantized=0.041667, n=488
#   Trial 4: original=0.048828, quantized=0.041667, n=512
#   Trial 5: original=0.053030, quantized=0.041667, n=528
#   Trial 6: original=0.046000, quantized=0.041667, n=500
#   Trial 7: original=0.033557, quantized=0.041667, n=447
#   Trial 8: original=0.047431, quantized=0.041667, n=506
#   Trial 9: original=0.054307, quantized=0.041667, n=534
#   Trial 10: original=0.031891, quantized=0.041667, n=439
#   ✓ All 10 trials exactly repeatable!
#
# Importance Sampling with Bernoulli(0.150):
# Demonstrating exact repeatability for Bernoulli(0.050)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.057191, quantized=0.041667, n=426
#   Trial 2: original=0.047989, quantized=0.041667, n=415
#   Trial 3: original=0.052676, quantized=0.041667, n=420
#   Trial 4: original=0.053432, quantized=0.041667, n=421
#   Trial 5: original=0.045822, quantized=0.041667, n=411
#   Trial 6: original=0.047354, quantized=0.041667, n=413
#   Trial 7: original=0.047989, quantized=0.041667, n=415
#   Trial 8: original=0.041971, quantized=0.041667, n=406
#   Trial 9: original=0.045054, quantized=0.041667, n=410
#   Trial 10: original=0.052676, quantized=0.041667, n=420
#   ✓ All 10 trials exactly repeatable!
#
# --- Beta(0.5, 2.0) with γ=0.05 ---
# Demonstrating exact repeatability for Beta(0.5, 2.0)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.199338, quantized=0.227273, n=404
#   Trial 2: original=0.192732, quantized=0.227273, n=380
#   Trial 3: original=0.202239, quantized=0.227273, n=415
#   Trial 4: original=0.190185, quantized=0.227273, n=406
#   Trial 5: original=0.198691, quantized=0.227273, n=395
#   Trial 6: original=0.214971, quantized=0.227273, n=432
#   Trial 7: original=0.204119, quantized=0.227273, n=416
#   Trial 8: original=0.192269, quantized=0.227273, n=384
#   Trial 9: original=0.192215, quantized=0.227273, n=406
#   Trial 10: original=0.205864, quantized=0.227273, n=418
#   ✓ All 10 trials exactly repeatable!
#
# --- Beta(0.5, 2.0) with γ=0.05 ---
# Demonstrating exact repeatability for Beta(0.5, 2.0)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.186610, quantized=0.208333, n=480
#   Trial 2: original=0.203308, quantized=0.208333, n=510
#   Trial 3: original=0.217124, quantized=0.208333, n=538
#   Trial 4: original=0.223888, quantized=0.208333, n=531
#   Trial 5: original=0.207371, quantized=0.208333, n=530
#   Trial 6: original=0.208624, quantized=0.208333, n=516
#   Trial 7: original=0.204743, quantized=0.208333, n=517
#   Trial 8: original=0.213181, quantized=0.208333, n=529
#   Trial 9: original=0.208073, quantized=0.208333, n=521
#   Trial 10: original=0.210209, quantized=0.208333, n=535
#   ✓ All 10 trials exactly repeatable!
#
# --- TruncNorm(μ=0.30, σ=0.15) with γ=0.05 ---
# Demonstrating exact repeatability for TruncNorm(μ=0.30, σ=0.15)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.307693, quantized=0.318182, n=311
#   Trial 2: original=0.307391, quantized=0.318182, n=310
#   Trial 3: original=0.299641, quantized=0.318182, n=315
#   Trial 4: original=0.309654, quantized=0.318182, n=309
#   Trial 5: original=0.286875, quantized=0.318182, n=298
#   Trial 6: original=0.306637, quantized=0.318182, n=311
#   Trial 7: original=0.296524, quantized=0.318182, n=310
#   Trial 8: original=0.298239, quantized=0.318182, n=317
#   Trial 9: original=0.308676, quantized=0.318182, n=302
#   Trial 10: original=0.295334, quantized=0.318182, n=297
#   ✓ All 10 trials exactly repeatable!
#
# Importance Sampling with Beta(1.0, 1.0):
# Demonstrating exact repeatability for TruncNorm(μ=0.30, σ=0.15)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.303628, quantized=0.318182, n=2076
#   Trial 2: original=0.303271, quantized=0.318182, n=2076
#   Trial 3: original=0.306121, quantized=0.318182, n=2088
#   Trial 4: original=0.309803, quantized=0.318182, n=2098
#   Trial 5: original=0.302356, quantized=0.318182, n=2065
#   Trial 6: original=0.303213, quantized=0.318182, n=2043
#   Trial 7: original=0.299101, quantized=0.318182, n=2061
#   Trial 8: original=0.308127, quantized=0.318182, n=2074
#   Trial 9: original=0.304122, quantized=0.318182, n=2072
#   Trial 10: original=0.310520, quantized=0.318182, n=2059
#   ✓ All 10 trials exactly repeatable!
#
# --- TruncNorm(μ=0.30, σ=0.15) with γ=0.05 ---
# Demonstrating exact repeatability for TruncNorm(μ=0.30, σ=0.15)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.306339, quantized=0.291667, n=380
#   Trial 2: original=0.298519, quantized=0.291667, n=381
#   Trial 3: original=0.314562, quantized=0.291667, n=387
#   Trial 4: original=0.311799, quantized=0.291667, n=374
#   Trial 5: original=0.306182, quantized=0.291667, n=384
#   Trial 6: original=0.328344, quantized=0.291667, n=392
#   Trial 7: original=0.307531, quantized=0.291667, n=372
#   Trial 8: original=0.326392, quantized=0.291667, n=374
#   Trial 9: original=0.314955, quantized=0.291667, n=385
#   Trial 10: original=0.314009, quantized=0.291667, n=384
#   ✓ All 10 trials exactly repeatable!
#
# Importance Sampling with Beta(1.0, 1.0):
# Demonstrating exact repeatability for TruncNorm(μ=0.30, σ=0.15)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.307359, quantized=0.291667, n=2592
#   Trial 2: original=0.302910, quantized=0.291667, n=2584
#   Trial 3: original=0.309777, quantized=0.291667, n=2588
#   Trial 4: original=0.309868, quantized=0.291667, n=2586
#   Trial 5: original=0.308014, quantized=0.291667, n=2590
#   Trial 6: original=0.307812, quantized=0.291667, n=2574
#   Trial 7: original=0.306833, quantized=0.291667, n=2591
#   Trial 8: original=0.306959, quantized=0.291667, n=2611
#   Trial 9: original=0.302395, quantized=0.291667, n=2593
#   Trial 10: original=0.305338, quantized=0.291667, n=2580
#   ✓ All 10 trials exactly repeatable!
#
# --- BiModal(w=0.30) with γ=0.05 ---
# Demonstrating exact repeatability for BiModal(w=0.30)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.615802, quantized=0.590909, n=670
#   Trial 2: original=0.629984, quantized=0.590909, n=646
#   Trial 3: original=0.602958, quantized=0.590909, n=686
#   Trial 4: original=0.628945, quantized=0.590909, n=674
#   Trial 5: original=0.634547, quantized=0.590909, n=634
#   Trial 6: original=0.627297, quantized=0.590909, n=643
#   Trial 7: original=0.617515, quantized=0.590909, n=661
#   Trial 8: original=0.627400, quantized=0.590909, n=641
#   Trial 9: original=0.607866, quantized=0.590909, n=671
#   Trial 10: original=0.601177, quantized=0.590909, n=674
#   ✓ All 10 trials exactly repeatable!
#
# Importance Sampling with Beta(1.0, 1.0):
# Demonstrating exact repeatability for BiModal(w=0.30)
# Parameters: γ=0.05, c=0.05, β=0.1
# Computed α=0.094737
#   Trial 1: original=0.619219, quantized=0.590909, n=5000
#   Trial 2: original=0.622254, quantized=0.590909, n=5000
#   Trial 3: original=0.615802, quantized=0.590909, n=5000
#   Trial 4: original=0.616925, quantized=0.590909, n=5000
#   Trial 5: original=0.611163, quantized=0.590909, n=5000
#   Trial 6: original=0.626204, quantized=0.590909, n=5000
#   Trial 7: original=0.634018, quantized=0.590909, n=5000
#   Trial 8: original=0.640069, quantized=0.681818, n=5000
#   Trial 9: original=0.625173, quantized=0.590909, n=5000
#   Trial 10: original=0.617309, quantized=0.590909, n=5000
#   ⚠ Trial 8 NOT exactly repeatable! (quantized: 0.681818 vs 0.590909)
#   Repeatability: 9/10 trials repeatable (90.0% vs 90.0% theoretical)
#
# --- BiModal(w=0.30) with γ=0.05 ---
# Demonstrating exact repeatability for BiModal(w=0.30)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.620920, quantized=0.625000, n=835
#   Trial 2: original=0.613000, quantized=0.625000, n=811
#   Trial 3: original=0.608798, quantized=0.625000, n=842
#   Trial 4: original=0.606756, quantized=0.625000, n=841
#   Trial 5: original=0.635302, quantized=0.625000, n=806
#   Trial 6: original=0.601055, quantized=0.625000, n=810
#   Trial 7: original=0.625433, quantized=0.625000, n=817
#   Trial 8: original=0.645308, quantized=0.625000, n=797
#   Trial 9: original=0.612206, quantized=0.625000, n=837
#   Trial 10: original=0.621873, quantized=0.625000, n=827
#   ✓ All 10 trials exactly repeatable!
#
# Importance Sampling with Beta(1.0, 1.0):
# Demonstrating exact repeatability for BiModal(w=0.30)
# Parameters: γ=0.05, c=0.02, β=0.05
# Computed α=0.089594
#   Trial 1: original=0.616727, quantized=0.625000, n=10000
#   Trial 2: original=0.635197, quantized=0.625000, n=10000
#   Trial 3: original=0.621301, quantized=0.625000, n=10000
#   Trial 4: original=0.618771, quantized=0.625000, n=10000
#   Trial 5: original=0.640028, quantized=0.625000, n=10000
#   Trial 6: original=0.623531, quantized=0.625000, n=10000
#   Trial 7: original=0.620369, quantized=0.625000, n=10000
#   Trial 8: original=0.631151, quantized=0.625000, n=10000
#   Trial 9: original=0.632003, quantized=0.625000, n=10000
#   Trial 10: original=0.636265, quantized=0.625000, n=10000
#   ✓ All 10 trials exactly repeatable!
#
# 2. EMPIRICAL BERNSTEIN STOPPING CRITERION
# --------------------------------------------------
# γ=0.050: n=456, empirical_var=0.059552, converged=True
# γ=0.020: n=1557, empirical_var=0.044104, converged=True
